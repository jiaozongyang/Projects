# %% [markdown]
# # Strategy 1

# %%
# %run Strategy1.py

# %%
portfolio1.head()
# Out:
#             EEM US Equity & NDUEEGF Index  SX5E Index   SPX Index   NKY Index  \
# date
# 2010-01-29                    -129.317269 -105.751848  -61.623771  -55.058073
# 2010-02-26                      27.657395  -27.115104   44.394356  -10.993865
# 2010-03-31                     127.880637  117.013962   92.613659  149.941490
# 2010-04-30                      -2.893363  -65.103763   24.641432   -4.898778
# 2010-05-31                    -153.740195 -120.038729 -134.166043 -190.745869
#
#              HSI Index  SHSZ300 Index & SHCOMP Index  \
# date
# 2010-01-29 -133.387435                   -173.169859
# 2010-02-26   37.659420                     37.663253
# 2010-03-31   48.201699                     30.690380
# 2010-04-30  -10.278579                   -138.854272
# 2010-05-31 -104.160355                   -156.923002
#
#             10yr proxy-10yr treasury rate&SH000012 Index&CSIH1077 Index & CN10yr builder  \
# date
# 2010-01-29                                                0.0
# ...

# %%
cache1
# Out:
# {'effective_annual_return': 0.05096670241665535,
#  'sharp_ratio': 1.1721556097361017,
#  'volatility': 0.06637928630395432,
#  'maximum_drawdown': 0.10935183580694127,
#  'calmar_ratio': 0.4660799888777008,
#  'drawdown_start': Timestamp('2010-04-30 00:00:00'),
#  'drawdown_end': Timestamp('2011-02-28 00:00:00')}

# %% [markdown]
# ## Weight of Asset Classes

# %%
# weights of assets
plt.plot(signals)
plt.legend(('Stock','Bond'))
plt.xlabel('Time')
plt.ylabel('Weight')
plt.title('Asset Weights from 2010 to 2019');
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Equity Curve

# %%
plt.plot(portfolio1['Start_Capital'])
plt.xlabel('Time')
plt.ylabel('Capital')
plt.title('Equity Variation from 2010 to 2019');

# %% [markdown]
# ## Maximum Drawdown

# %%
equity1 = portfolio1['Start_Capital']
i1 = cache1['drawdown_end']
j1 = cache1['drawdown_start']
plt.plot(equity1)
plt.plot([j1,i1],[equity1[j1],equity1[i1]],'o',color='Red')
plt.title('Maximum Drawdown');

# %% [markdown]
# # Strategy 2

# %%
# %run Strategy2.py

# %%
portfolio2.head()
# Out:
#             EEM US Equity & NDUEEGF Index  SX5E Index  SPX Index   NKY Index  \
# date
# 2010-01-29                    -122.546196 -100.214664 -58.397140  -52.175224
# 2010-02-26                      25.153434  -24.660240  40.375115   -9.998536
# 2010-03-31                     109.289321  100.002446  79.149465  128.142963
# 2010-04-30                      -2.240279  -50.408666  19.079415   -3.793035
# 2010-05-31                    -102.229392  -79.819635 -89.213579 -126.836279
#
#              HSI Index  SHSZ300 Index & SHCOMP Index  \
# date
# 2010-01-29 -126.403247                   -164.102656
# 2010-02-26   34.249926                     34.253412
# 2010-03-31   41.194126                     26.228606
# 2010-04-30   -7.958518                   -107.512351
# 2010-05-31  -69.261326                   -104.345797
#
#             10yr proxy-10yr treasury rate&SH000012 Index&CSIH1077 Index & CN10yr builder  \
# date
# 2010-01-29                                           0.847664
# ...

# %%
cache2
# Out:
# {'effective_annual_return': 0.04575899807601891,
#  'sharp_ratio': 1.2160862640058832,
#  'volatility': 0.050126815079689316,
#  'maximum_drawdown': 0.08458910342124945,
#  'calmar_ratio': 0.5409561778677499,
#  'drawdown_start': Timestamp('2010-01-29 00:00:00'),
#  'drawdown_end': Timestamp('2011-02-28 00:00:00')}

# %% [markdown]
# ## Weight of Asset Classes

# %%
# weights of assets
plt.plot(signals)
plt.legend(('Stock','Bond'))
plt.xlabel('Time')
plt.ylabel('Weight')
plt.title('Asset Weights from 2010 to 2019');

# %% [markdown]
# ## Equity Curve

# %%
plt.plot(portfolio2['Start_Capital'])
plt.xlabel('Time')
plt.ylabel('Capital')
plt.title('Equity Variation from 2010 to 2019');

# %% [markdown]
# ## Maximum Drawdown

# %%
equity2 = portfolio2['Start_Capital']
i2 = cache2['drawdown_end']
j2 = cache2['drawdown_start']
plt.plot(equity2)
plt.plot([j2,i2],[equity2[j2],equity2[i2]],'o',color='Red')
plt.title('Maximum Drawdown');

# %% [markdown]
# # Strategy 3

# %%
# %run Strategy3.py

# %%
portfolio3.head()
# Out:
#             EEM US Equity & NDUEEGF Index  SX5E Index  SPX Index  NKY Index  \
# date
# 2010-01-29                      22.933860   -8.063628  17.753764  -4.181506
# 2010-02-26                      29.799833    8.843017  27.451336   0.543133
# 2010-03-31                      26.783212   14.488177  28.008151   6.831404
# 2010-04-30                      23.980602   -0.959518  18.575051 -16.717353
# 2010-05-31                      28.721792    9.584648  20.706522 -15.169077
#
#             HSI Index  SHSZ300 Index & SHCOMP Index  \
# date
# 2010-01-29   7.384653                    -17.378979
# 2010-02-26  22.952708                     -5.533171
# 2010-03-31  18.393796                     -1.782206
# 2010-04-30  14.962859                     -5.077965
# 2010-05-31  17.187710                      5.676253
#
#             10yr proxy-10yr treasury rate&SH000012 Index&CSIH1077 Index & CN10yr builder  \
# date
# 2010-01-29                                                0.0
# ...

# %%
position3.head(15)
# Out:
#             EEM US Equity & NDUEEGF Index  SX5E Index   SPX Index   NKY Index  \
# date
# 2010-01-29                     138.888889  138.888889  138.888889  138.888889
# 2010-02-26                     138.888889  138.888889  138.888889  138.888889
# 2010-03-31                     138.888889  138.888889  138.888889  138.888889
# 2010-04-30                     138.888889  138.888889  138.888889  138.888889
# 2010-05-31                     138.888889  138.888889  138.888889  138.888889
# 2010-06-30                       0.000000    0.000000    0.000000    0.000000
# 2010-07-30                       0.000000    0.000000    0.000000    0.000000
# 2010-08-31                       0.000000    0.000000    0.000000    0.000000
# 2010-09-30                       0.000000    0.000000    0.000000    0.000000
# 2010-10-29                       0.000000    0.000000    0.000000    0.000000
# 2010-11-30                       0.000000    0.000000    0.000000    0.000000
# ...

# %%
cache3
# Out:
# {'effective_annual_return': 0.055133514478428625,
#  'sharp_ratio': 1.085473095682231,
#  'volatility': 0.0518081447809722,
#  'maximum_drawdown': 0.009188258221975372,
#  'calmar_ratio': 6.00043154496539,
#  'drawdown_start': Timestamp('2017-06-30 00:00:00'),
#  'drawdown_end': Timestamp('2018-03-30 00:00:00')}

# %% [markdown]
# ## Weight of Asset Classes

# %%
plt.plot(position3[['StockWeight','BondWeight']])
plt.legend(('Stock','Bond'))
plt.xlabel('Time')
plt.ylabel('Weight')
plt.title('Asset Weights from 2011 to 2019');

# %% [markdown]
# ## Equity Curve

# %%
plt.plot(portfolio3['Start_Capital'])
plt.xlabel('Time')
plt.ylabel('Capital')
plt.title('Equity Variation from 2011 to 2019');

# %% [markdown]
# ## Maximum Drawdown

# %%
equity3 = portfolio3['Start_Capital'].dropna()
i3 = cache3['drawdown_end']
j3 = cache3['drawdown_start']
plt.plot(equity3)
plt.plot([j3,i3],[equity3[j3],equity3[i3]],'o',color='Red')
plt.title('Maximum Drawdown');

# %% [markdown]
# # Strategy 4

# %%
# %run Strategy4.py

# %%
portfolio4.head()
# Out:
#             EEM US Equity & NDUEEGF Index  SX5E Index  SPX Index  NKY Index  \
# date
# 2010-01-29                      21.733039   -7.641415  16.824174  -3.962561
# 2010-02-26                      26.984555    8.007591  24.857927   0.491821
# 2010-03-31                      22.800920   12.333986  23.843727   5.815669
# 2010-04-30                      18.658100   -0.746552  14.452313 -13.006932
# 2010-05-31                      19.055559    6.358963  13.737804 -10.063970
#
#             HSI Index  SHSZ300 Index & SHCOMP Index  \
# date
# 2010-01-29   6.997992                    -16.469013
# 2010-02-26  20.784298                     -5.010436
# 2010-03-31  15.658894                     -1.517216
# 2010-04-30  11.641848                     -3.950909
# 2010-05-31  11.403238                      3.765927
#
#             10yr proxy-10yr treasury rate&SH000012 Index&CSIH1077 Index & CN10yr builder  \
# date
# 2010-01-29                                           0.169479
# ...

# %%
position4.head(15)
# Out:
#             EEM US Equity & NDUEEGF Index  SX5E Index   SPX Index   NKY Index  \
# date
# 2010-01-29                     131.616644  131.616644  131.616644  131.616644
# 2010-02-26                     125.767645  125.767645  125.767645  125.767645
# 2010-03-31                     118.238038  118.238038  118.238038  118.238038
# 2010-04-30                     108.062459  108.062459  108.062459  108.062459
# 2010-05-31                      92.146251   92.146251   92.146251   92.146251
# 2010-06-30                      63.663455   63.663455   63.663455   63.663455
# 2010-07-30                       8.347940    8.347940    8.347940    8.347940
# 2010-08-31                       0.000000    0.000000    0.000000    0.000000
# 2010-09-30                       0.000000    0.000000    0.000000    0.000000
# 2010-10-29                       0.000000    0.000000    0.000000    0.000000
# 2010-11-30                       0.000000    0.000000    0.000000    0.000000
# ...

# %%
cache4
# Out:
# {'effective_annual_return': 0.05674141959540391,
#  'sharp_ratio': 1.716928887265936,
#  'volatility': 0.033290164386685556,
#  'maximum_drawdown': 0.000879109504741584,
#  'calmar_ratio': 64.54419988563673,
#  'drawdown_start': Timestamp('2018-10-31 00:00:00'),
#  'drawdown_end': Timestamp('2018-11-30 00:00:00')}

# %% [markdown]
# ## Weight of Asset Classes

# %%
plt.plot(position4[['StockWeight','BondWeight']])
plt.legend(('Stock','Bond'))
plt.xlabel('Time')
plt.ylabel('Weight')
plt.title('Asset Weights from 2011 to 2019');

# %% [markdown]
# ## Equity Curve

# %%
plt.plot(portfolio4['Start_Capital'])
plt.xlabel('Time')
plt.ylabel('Capital')
plt.title('Equity Variation from 2011 to 2019');

# %% [markdown]
# ## Maximum Drawdown

# %%
equity4 = portfolio4['Start_Capital'].dropna()
i4 = cache4['drawdown_end']
j4 = cache4['drawdown_start']
plt.plot(equity4)
plt.plot([j4,i4],[equity4[j4],equity4[i4]],'o',color='Red')
plt.title('Maximum Drawdown');

# %%
measures = pd.DataFrame([cache1,cache2,cache3,cache4],index=['Strategy 1','Strategy 2','Strategy 3','Strategy 4'])

# %%
measures
# Out:
#             calmar_ratio drawdown_end drawdown_start  effective_annual_return  \
# Strategy 1      0.466080   2011-02-28     2010-04-30                 0.050967
# Strategy 2      0.540956   2011-02-28     2010-01-29                 0.045759
# Strategy 3      6.000432   2018-03-30     2017-06-30                 0.055134
# Strategy 4     64.544200   2018-11-30     2018-10-31                 0.056741
#
#             maximum_drawdown  sharp_ratio  volatility
# Strategy 1          0.109352     1.172156    0.066379
# Strategy 2          0.084589     1.216086    0.050127
# Strategy 3          0.009188     1.085473    0.051808
# Strategy 4          0.000879     1.716929    0.033290

# %% [markdown]
# # Strategy 5

# %%
# %run Strategy5.py

# %%
portfolio5.head()
# Out:
#             EEM US Equity & NDUEEGF Index  SX5E Index  SPX Index  NKY Index  \
# date
# 2010-01-29                      18.529766   -8.042941  20.601051  -4.440239
# 2010-02-26                      22.551530    8.373242  32.163046   0.591201
# 2010-03-31                      17.637277   13.427005  38.240691   6.398336
# 2010-04-30                      15.388219   -0.777117  24.000433 -13.506141
# 2010-05-31                      15.596731    7.064152  23.756866  -9.890078
#
#             HSI Index  SHSZ300 Index & SHCOMP Index  \
# date
# 2010-01-29   7.208212                    -11.853850
# 2010-02-26  20.412572                     -3.209495
# 2010-03-31  13.827372                     -0.835709
# 2010-04-30  10.050562                     -2.259738
# 2010-05-31   9.811693                      1.876028
#
#             10yr proxy-10yr treasury rate&SH000012 Index&CSIH1077 Index & CN10yr builder  \
# date
# 2010-01-29                                           0.259210
# ...

# %%
position5.head(18)
# Out:
#             EEM US Equity & NDUEEGF Index  SX5E Index   SPX Index   NKY Index  \
# date
# 2010-01-29                     112.217420  138.532575  161.163409  147.482732
# 2010-02-26                     105.106524  131.510575  162.727588  151.180912
# 2010-03-31                      91.461092  128.716109  189.630766  130.084219
# 2010-04-30                      89.124232  112.486684  179.455414  112.209921
# 2010-05-31                      75.420528  102.364974  159.349061   90.554086
# 2010-06-30                      58.462786   69.165845   89.358525   58.909982
# 2010-07-30                       7.812151    9.227530   10.847089    7.860880
# 2010-08-31                       0.000000    0.000000    0.000000    0.000000
# 2010-09-30                       0.000000    0.000000    0.000000    0.000000
# 2010-10-29                       0.000000    0.000000    0.000000    0.000000
# 2010-11-30                       0.000000    0.000000    0.000000    0.000000
# ...

# %%
cache5
# Out:
# {'effective_annual_return': 0.053379257715773676,
#  'sharp_ratio': 1.6104018576056862,
#  'volatility': 0.0334021914404868,
#  'maximum_drawdown': 0.0005889329999767043,
#  'calmar_ratio': 90.63723329798998,
#  'drawdown_start': Timestamp('2018-10-31 00:00:00'),
#  'drawdown_end': Timestamp('2018-11-30 00:00:00')}

# %% [markdown]
# ## Weight of Asset Class

# %%
plt.plot(position5[['StockWeight','BondWeight']])
plt.legend(('Stock','Bond'))
plt.xlabel('Time')
plt.ylabel('Weight')
plt.title('Asset Weights from 2011 to 2019');

# %% [markdown]
# ## Equity Curve

# %%
plt.plot(portfolio5['Start_Capital'])
plt.xlabel('Time')
plt.ylabel('Capital')
plt.title('Equity Variation from 2011 to 2019');

# %% [markdown]
# ## Maximum Drawdown

# %%
equity5 = portfolio5['Start_Capital'].dropna()
i5 = cache5['drawdown_end']
j5 = cache5['drawdown_start']
plt.plot(equity5)
plt.plot([j5,i5],[equity5[j5],equity5[i5]],'o',color='Red')
plt.title('Maximum Drawdown');

# %% [markdown]
# # Summary

# %%
plt.plot(equity1)
plt.plot(equity2)
plt.plot(equity3)
plt.plot(equity4)
plt.plot(equity5)
plt.legend(('Strategy 1','Strategy 2','Strategy 3','Strategy 4','Strategy 5'))
plt.xlabel('Time')
plt.ylabel('Equity')
plt.title('Backtest Equity Change of 5 Strategies');
#plt.savefig('equity.png')

# %%
measures = pd.DataFrame([cache1,cache2,cache3,cache4,cache5],index=['Strategy 1','Strategy 2','Strategy 3','Strategy 4','Strategy 5'])

# %%
measures
# Out:
#             calmar_ratio drawdown_end drawdown_start  effective_annual_return  \
# Strategy 1      0.466080   2011-02-28     2010-04-30                 0.050967
# Strategy 2      0.540956   2011-02-28     2010-01-29                 0.045759
# Strategy 3      6.000432   2018-03-30     2017-06-30                 0.055134
# Strategy 4     64.544200   2018-11-30     2018-10-31                 0.056741
# Strategy 5     90.637233   2018-11-30     2018-10-31                 0.053379
#
#             maximum_drawdown  sharp_ratio  volatility
# Strategy 1          0.109352     1.172156    0.066379
# Strategy 2          0.084589     1.216086    0.050127
# Strategy 3          0.009188     1.085473    0.051808
# Strategy 4          0.000879     1.716929    0.033290
# Strategy 5          0.000589     1.610402    0.033402

# %%
#measures.to_csv("measures.csv")
